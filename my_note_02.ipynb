# %% [markdown]
# # Python数据分析简介

# %% [markdown]
# ### Numpy

# %%
import numpy as np

# %%
a = np.array([2, 0, 1, 5])
print(a)
print(a[:3])
print(a.min())
a.sort()
b = np.array([[1, 2, 3], [4, 5, 6]])
print(b*b)
# Out:
# [2 0 1 5]
# [2 0 1]
# 0
# [[ 1  4  9]
#  [16 25 36]]

# %% [markdown]
# ### Scipy

# %%
from scipy.optimize import fsolve

# %%
# 求解方程组 2x1 - x2^2 = 1, x1^2 - x2 = 2
def f(x):
    x1 = x[0]
    x2 = x[1]
    return [2*x1 - x2**2 - 1, x1**2 - x2 - 2]

result = fsolve(f, [1, 1])
print(result)
# Out:
# [1.91963957 1.68501606]

# %%
from scipy import integrate

# %%
def g(x):
    return (1-x**2)**0.5

pi_2, err = integrate.quad(g, -1, 1)
print(pi_2 * 2)
# Out:
# 3.141592653589797

# %% [markdown]
# ### Matplotlib

# %%
import matplotlib.pyplot as plt

# %%
plt.rcParams['font.sans-serif'] = ['SimHei']

# %%
x = np.linspace(0, 10, 1000)
y = np.sin(x) + 1
z = np.cos(x**2) + 1

plt.figure(figsize=(8, 4))
plt.plot(x, y, 'r-', label='sinx + 1')
plt.plot(x, z, 'b--', label='cosx^2 + 1')
plt.legend(loc='upper right')
plt.xlabel('时间')
plt.show()

# %% [markdown]
# ### Pandas

# %%
import pandas as pd

# %%
s = pd.Series([1, 2, 3], index=['a', 'b', 'c'])
d = pd.DataFrame([[1, 2, 3], [4, 5, 6]], columns=['a', 'b', 'c'])
d2 = pd.DataFrame(s)
d.head()
# Out:
#    a  b  c
# 0  1  2  3
# 1  4  5  6

# %%
d2.head()
# Out:
#    0
# a  1
# b  2
# c  3

# %%
d.describe()
# Out:
#              a        b        c
# count  2.00000  2.00000  2.00000
# mean   2.50000  3.50000  4.50000
# std    2.12132  2.12132  2.12132
# min    1.00000  2.00000  3.00000
# 25%    1.75000  2.75000  3.75000
# 50%    2.50000  3.50000  4.50000
# 75%    3.25000  4.25000  5.25000
# max    4.00000  5.00000  6.00000

# %% [markdown]
# ### StarsModels

# %%
from statsmodels.tsa.stattools import adfuller as ADF

# %%
ADF(np.random.rand(100))
# Out:
# (-10.395322204340532,
#  1.972139708638978e-18,
#  0,
#  99,
#  {'1%': -3.498198082189098,
#   '5%': -2.891208211860468,
#   '10%': -2.5825959973472097},
#  30.52863860899123)

# %% [markdown]
# ### Scikit-Learn

# %%
from sklearn import datasets
from sklearn import svm

# %%
iris = datasets.load_iris()
clf = svm.LinearSVC(max_iter=10000)
clf.fit(iris.data, iris.target)
clf.coef_
# Out:
# array([[ 0.18423782,  0.45122906, -0.80794125, -0.45071634],
#        [ 0.0552478 , -0.90089877,  0.40923129, -0.96062655],
#        [-0.85059421, -0.98655844,  1.3810373 ,  1.86512322]])

# %% [markdown]
# ### Keras

# %%
import tensorflow as tf
from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation
from keras.optimizers import SGD
# Out:
# Using TensorFlow backend.

# %%
model = Sequential()
model.add(Dense(64))
model.add(Activation('tanh'))
model.add(Dropout(0.5))
model.add(Dense(64))
model.add(Activation('tanh'))
model.add(Dropout(0.5))
model.add(Dense(1))
model.add(Activation('sigmoid'))
sgd = SGD(lr=0.1, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='mean_squared_error', optimizer=sgd)
# model.fit(X_train, y_train, nb_epoch=20, batch_size=16)
# score = model.evaluate(X_test, y_test, batch_size=16)
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0724 01:06:33.133072 10100 deprecation_wrapper.py:119] From C:\ProgramData\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0724 01:06:33.187951 10100 deprecation_wrapper.py:119] From C:\ProgramData\Anaconda3\lib\site-packages\keras\optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %% [markdown]
# ### Gensim

# %%
import gensim, logging

# %%
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)
sentences = [['first', 'sentence'], ['second', 'sentence']]
model = gensim.models.Word2Vec(sentences, min_count=1)
print(model['sentence'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\gensim\models\base_any2vec.py:743: UserWarning: C extension not loaded, training will be slow. Install a C compiler and reinstall gensim for fast training.
#   "C extension not loaded, training will be slow. "
# W0724 01:06:33.425290 10100 base_any2vec.py:1386] under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# [-4.78455657e-03 -3.22778895e-03  2.84725404e-03 -3.56169348e-03
#  -3.92049970e-03 -1.44248130e-04  8.37004103e-04  3.50367231e-03
#  -4.37175389e-03  3.50346137e-03  1.87391276e-03  3.39307683e-03
#  -2.54723895e-03  2.42283917e-03  2.14413484e-03  2.69934721e-03
#   1.26064394e-03 -4.86431550e-03  3.64151923e-03  2.90155993e-03
#  -2.67652504e-04 -2.60617281e-03 -4.67115315e-03  1.87982712e-03
#   1.06058906e-04  3.34875961e-03 -3.59520083e-03  3.61070596e-03
#  -4.61939164e-03 -8.80215375e-04  3.16845882e-03  3.87789146e-03
#  -1.41744828e-03  3.80122568e-03 -4.11423901e-03  1.43383644e-04
#   2.93914089e-03 -5.92002005e-04 -4.35463386e-03  2.93585612e-03
#  -6.80413679e-04 -2.70386925e-03  4.40887036e-03  8.58131854e-04
#   3.15638863e-05  3.44464416e-03 -3.04970308e-03  7.96979293e-04
#  -5.73270663e-04 -4.63608885e-03  3.54810734e-03 -2.07892735e-03
#   2.59480649e-03 -4.92378464e-03  2.67502479e-03  1.61702849e-03
#   3.85055435e-03  4.61793831e-03 -3.60147981e-03 -1.96281611e-03
#   4.45058011e-03 -2.16217060e-03  4.84287133e-03  3.69111961e-03
#  -4.62515745e-03 -4.45564883e-03  4.98737022e-03 -4.41730116e-03
#   1.19306496e-03  3.08285537e-03  4.43474948e-03 -3.12561798e-03
#  -1.52239599e-03 -4.33635013e-03  4.68730181e-03 -3.43002682e-03
#  -3.81400622e-03 -4.17581061e-03 -8.87664966e-04 -3.89233767e-03
#   2.45660474e-03  2.30800244e-03 -1.33842661e-03  4.93614329e-03
#   1.83022479e-04  4.87083429e-03  1.91658002e-03 -4.73631173e-03
#   2.33579916e-03 -4.64760466e-03  1.28709551e-04 -3.75042576e-03
#  -2.25685514e-03 -3.75459739e-03  3.42294900e-03  4.78284946e-03
#  -3.58490716e-03  3.35837156e-03 -1.35266548e-03 -2.01874902e-03]
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   after removing the cwd from sys.path.
